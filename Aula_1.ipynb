# %%
# Validação de bibliotecas essenciais para o curso de MBA em Engenharia de Dados / Data Science

import importlib

# Todas as dependências do projeto definidas em pyproject.toml
libs = [
    # Core
    "pandas",
    "numpy",
    # Estatística
    "scipy",
    "statsmodels",
    # Machine Learning
    "sklearn",
    # Visualização
    "matplotlib",
    "seaborn",
    # Notebooks
    "jupyterlab",
    # Performance
    "polars",
    # Dev
    "black",
    "ruff",
    "ipykernel"
]

for lib in libs:
    try:
        importlib.import_module(lib)
        print(f"✅ {lib} OK")
    except ImportError:
        print(f"❌ {lib} NOT INSTALLED")
# Out:
# ✅ pandas OK
# ✅ numpy OK
# ✅ scipy OK
# ✅ sklearn OK
# ✅ matplotlib OK
